# %% [markdown]
# # Exploratory Data Analysis on Superheroes Dataset ( Bivariate Analysis )

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns', None) # so that we can see all the columns
temp = pd.read_csv('D:\\Study\\EDA on Superheroes\\Cleaned_data\\cleaned_data_superheroes.csv')

sups = temp.copy()

# %%
sups.columns
# Out:
# Index(['name', 'overall_score', 'intelligence_score', 'strength_score',
#        'speed_score', 'durability_score', 'power_score', 'combat_score',
#        'superpowers', 'alter_egos', 'aliases', 'place_of_birth',
#        'first_appearance', 'creator', 'alignment', 'occupation', 'base',
#        'teams', 'gender', 'type_race', 'height(cm)', 'weight(lb)', 'eye_color',
#        'hair_color', 'skin_color', 'has_electrokinesis',
#        'has_energy_constructs', 'has_mind_control_resistance',
#        'has_matter_manipulation', 'has_telepathy_resistance',
#        'has_mind_control', 'has_enhanced_hearing', 'has_dimensional_travel',
#        'has_element_control', 'has_size_changing', 'has_fire_resistance',
#        'has_fire_control', 'has_dexterity', 'has_reality_warping',
#        'has_illusions', 'has_energy_beams', 'has_peak_human_condition',
#        'has_shapeshifting', 'has_heat_resistance', 'has_jump',
# ...

# %%
sups.head()
# Out:
#             name  overall_score  intelligence_score  strength_score  \
# 0        3-D Man              6                  85              30
# 1  514A (Gotham)             10                 100              20
# 2         A-Bomb             20                  80             100
# 3             Aa             12                  80              50
# 4     Aaron Cash              5                  80              10
#
#    speed_score  durability_score  power_score  combat_score  \
# 0           60                60           40            70
# 1           30                50           35           100
# 2           80               100          100            80
# 3           55                45          100            55
# 4           25                40           30            50
#
#                                          superpowers  \
# 0                  ['Super Speed', 'Super Strength']
# 1       ['Durability', 'Reflexes', 'Super Strength']
# ...

# %% [markdown]
# ### Is there a correlation between "intelligence_score" and "overall_score" among superheroes?

# %%
correlation = sups['intelligence_score'].corr(sups['overall_score'])
correlation
# Out:
# 0.2676337863838347

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='intelligence_score', y='overall_score', data=sups)
plt.title("Relationship between Intelligence Score and Overall Score")
plt.xlabel("Intelligence Score")
plt.ylabel("Overall Score")
plt.show()

# %% [markdown]
# ### Is there a correlation between "overall_score" and "strength_score" among superheroes?

# %%
correlation = sups['overall_score'].corr(sups['strength_score'])
correlation
# Out:
# 0.47874925410506664

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='strength_score', y='overall_score', data=sups)
plt.title("Relationship between Intelligence Score and Strength Score")
plt.xlabel("Overall Score")
plt.ylabel("")
plt.show()

# %% [markdown]
# ### Is there a correlation between "overall_score" and "speed_score" among superheroes?

# %%
correlation = sups['overall_score'].corr(sups['speed_score'])
correlation
# Out:
# 0.4903660429555531

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='speed_score', y='overall_score', data=sups)
plt.title("Relationship between Speed Score and Overall Score")
plt.xlabel("Speed Score")
plt.ylabel("Overall Score")
plt.show()

# %% [markdown]
# ### Is there a correlation between "overall_score" and "durability_score" among superheroes?

# %%
correlation = sups['overall_score'].corr(sups['durability_score'])
correlation
# Out:
# 0.4344191419503146

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='durability_score', y='overall_score', data=sups)
plt.title("Relationship between Durability Score and Overall Score")
plt.xlabel("Durability Score")
plt.ylabel("Overall Score")
plt.show()

# %% [markdown]
# ### Is there a correlation between "overall_score" and "power_score" among superheroes?

# %%
correlation = sups['overall_score'].corr(sups['power_score'])
correlation
# Out:
# 0.397198927299472

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='durability_score', y='overall_score', data=sups)
plt.title("Relationship between Power Score and Overall Score")
plt.xlabel("Power Score")
plt.ylabel("Overall Score")
plt.show()

# %% [markdown]
# ### Is there a correlation between "overall_score" and "combat_score" among superheroes?

# %%
correlation = sups['overall_score'].corr(sups['combat_score'])
correlation
# Out:
# 0.23158153979908785

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='combat_score', y='overall_score', data=sups)
plt.title("Relationship between Combat Score and Overall Score")
plt.xlabel("Combat Score")
plt.ylabel("Overall Score")
plt.show()

# %% [markdown]
# ### Is there a correlation between "overall_score" and "height(cm)" among superheroes?

# %%
correlation = sups['overall_score'].corr(sups['height(cm)'])
correlation
# Out:
# 0.025247528709373836

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='height(cm)', y='overall_score', data=sups)
plt.title("Relationship between Height and Overall Score")
plt.xlabel("Height")
plt.ylabel("Overall Score")
plt.show()

# %% [markdown]
# ### Is there a correlation between "overall_score" and "weight(lb)" among superheroes?

# %%
correlation = sups['overall_score'].corr(sups['weight(lb)'])
correlation
# Out:
# 0.11706343977751825

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='weight(lb)', y='overall_score', data=sups)
plt.title("Relationship between Weight and Overall Score")
plt.xlabel("Weight")
plt.ylabel("Overall Score")
plt.show()
